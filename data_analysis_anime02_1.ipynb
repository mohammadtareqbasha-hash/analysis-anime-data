# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadtareqbasha-hash/analysis-anime-data/blob/analysis/data_analysis_anime02_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas - numpy - matplotlib - seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud

# %%
df=pd.read_csv('/content/anime.csv')

# %% [markdown]
# # 1- explore data

# %%
#df.head()
#df.tail()
df.sample(4)
# Out:
#       anime_id                                        name  \
# 4351       299                           .hack//Liminality
# 2116     11777  Lupin III: Chi no Kokuin - Eien no Mermaid
# 3945       248                                 Ichigo 100%
# 8471      2642               Dorami-chan: A Blue Straw Hat
#
#                                        genre     type episodes  rating  \
# 4351                   Game, Mystery, Sci-Fi      OVA        4    6.74
# 2116      Action, Adventure, Comedy, Shounen  Special        1    7.35
# 3945  Comedy, Ecchi, Harem, Romance, Shounen       TV       12    6.84
# 8471                           Fantasy, Kids    Movie        1    5.28
#
#       members
# 4351    24304
# 2116     3069
# 3945    67310
# 8471      121

# %%
df.shape
# Out:
# (12294, 7)

# %%
df.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# anime_id    12294
# name        12292
# genre        3264
# type            6
# episodes      187
# rating        598
# members      6706
# dtype: int64

# %%
#df.isnull().sum()
df.isna().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %% [markdown]
# #2- clean data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['genre']=df['genre'].fillna(df['genre'].mode()[0])
df.isna().sum()
# Out:
# anime_id      0
# name          0
# genre         0
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df['type']=df['type'].fillna(df['type'].mode()[0])
df.isna().sum()
# Out:
# anime_id      0
# name          0
# genre         0
# type          0
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df['rating']=df['rating'].fillna(df['rating'].mode()[0])
df.isna().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %% [markdown]
# # 3- Data Analysis

# %%
df.sort_values(by='rating',ascending=False)
# Out:
#        anime_id                                     name  \
# 10464     33662  Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120              Spoon-hime no Swing Kitchen
# 9595      23005                         Mogura no Motoro
# 0         32281                           Kimi no Na wa.
# 9078      33607                             Kahei no Umi
# ...         ...                                      ...
# 8056        413                          Hametsu no Mars
# 8057      13405                       Utsu Musume Sayuri
# 8058       3287             Tenkuu Danzai Skelter+Heaven
# 12258     20007            Hi Gekiga Ukiyoe Senya Ichiya
# 9991      34476       Platonic Chain: Ansatsu Jikkouchuu
#
#                                       genre     type episodes  rating  members
# 10464                        Comedy, Parody    Movie        1   10.00       13
# 10400                       Adventure, Kids       TV  Unknown    9.60       47
# ...

# %%
df['genre'].value_counts().head(10)
# Out:
# genre
# Hentai                   885
# Comedy                   523
# Music                    301
# Kids                     199
# Comedy, Slice of Life    179
# Dementia                 137
# Fantasy, Kids            128
# Fantasy                  114
# Comedy, Kids             112
# Drama                    107
# Name: count, dtype: int64

# %%
df['rating'].value_counts().head(10)
# Out:
# rating
# 6.00    371
# 7.00     99
# 6.50     90
# 6.25     84
# 5.00     76
# 6.75     72
# 6.67     68
# 5.67     67
# 6.38     67
# 6.80     67
# Name: count, dtype: int64

# %%
df['rating'].value_counts().sort_index()
# Out:
# rating
# 1.67     1
# 1.92     1
# 2.00     1
# 2.14     1
# 2.37     1
#         ..
# 9.33     1
# 9.37     1
# 9.50     1
# 9.60     1
# 10.00    1
# Name: count, Length: 598, dtype: int64

# %%
type_counts=df['type'].value_counts()

# %%
plt.figure(figsize=(10,6))
plt.pie(type_counts,labels=type_counts.index,autopct='%1.1f%%',startangle=50)
plt.title('Anime Type Distribution')
plt.show()

# %%
sns.histplot(df['rating'],bins=20,kde=True,color='green',edgecolor='green')
plt.title("Total_rating_distrbution")
plt.show()

# %%
plt.hist(df['rating'],bins=30,color='red',edgecolor='black',orientation='horizontal')
plt.title("Total_rating_distrbution")
plt.show()

# %%
plt.hist(df['rating'],bins=30,color='orange',edgecolor='black')
plt.title("Total_rating_distrbution")
plt.show()

# %%
sns.boxplot(data=df,x='type',y='rating')
plt.title("Total_rating_distrbution")
plt.show()

# %%
df['episodes'] = pd.to_numeric(df['episodes'], errors='coerce')

# %%
corr = df[['episodes', 'rating', 'members']].corr()
sns.heatmap(corr,annot=True,linewidths=5,cmap='coolwarm')
plt.title("Total rating distrbution")
plt.show()

# %%
sns.barplot(data=df,x='type',y='rating',estimator='mean')
plt.title('type rating')
plt.show()

# %%
sns.scatterplot(data=df,x='rating',y='members',hue='type')
plt.title('relation')
plt.show()

# %%
from wordcloud import WordCloud

# %%
text=" ".join(df['name'])

# %%
text
# Out:
# 'Kimi no Na wa. Fullmetal Alchemist: Brotherhood Gintama° Steins;Gate Gintama&#039; Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou Hunter x Hunter (2011) Ginga Eiyuu Densetsu Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare Gintama&#039;: Enchousen Clannad: After Story Koe no Katachi Gintama Code Geass: Hangyaku no Lelouch R2 Haikyuu!! Second Season Sen to Chihiro no Kamikakushi Shigatsu wa Kimi no Uso Mushishi Zoku Shou 2nd Season Ookami Kodomo no Ame to Yuki Code Geass: Hangyaku no Lelouch Hajime no Ippo Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen Cowboy Bebop One Punch Man Mononoke Hime Suzumiya Haruhi no Shoushitsu Monogatari Series: Second Season Mushishi Zoku Shou Mushishi Tengen Toppa Gurren Lagann Great Teacher Onizuka Natsume Yuujinchou Go Hajime no Ippo: New Challenger Mushishi Zoku Shou: Suzu no Shizuku Natsume Yuujinchou Shi Howl no Ugoku Shiro Fate/Zero 2nd Season Kizumonogatari II: Nekketsu-hen Monster Bakuman. 3rd Season Death Note Gintama°: Aiz
# ...

# %%
wcloud=WordCloud(background_color='gray',width=1000,height=1000).generate(text)

# %%
plt.imshow(wcloud)
plt.axis('off')
plt.show()

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

# %%
EDA_report=ProfileReport(df,title='Anime_EDA_report',explorative=True)

# %%
EDA_report.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-05-11 19:05:33.737118&quot; name=date&gt;&lt;title&gt;Anime_EDA_report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
